# %%
import pandas as pd

# %%
# reading the CSV file
Report = pd.read_csv('C:/Users/dhris/data/anime.csv')

# %% [markdown]
# ### Preparation and Cleaning

# %%
Report
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
Report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
Report.shape  #Initial Shape
# Out:
# (12294, 7)

# %%
Report.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
type(Report)
# Out:
# pandas.core.frame.DataFrame

# %%
Report.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
Report.isna().any()
# Out:
# anime_id    False
# name        False
# genre        True
# type         True
# episodes    False
# rating       True
# members     False
# dtype: bool

# %%
Report.dropna(inplace=True)

# %%
Report
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
Report.shape #Shape after dropping NaN values
# Out:
# (12017, 7)

# %%
Report.loc[(Report["type"] == "TV"), ["name", "episodes", "rating"]]
# Out:
#                                                     name episodes  rating
# 1                       Fullmetal Alchemist: Brotherhood       64    9.26
# 2                                               Gintama°       51    9.25
# 3                                            Steins;Gate       24    9.17
# 4                                          Gintama&#039;       51    9.16
# 5      Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...       10    9.15
# ...                                                  ...      ...     ...
# 11104                          Wake Up, Girls! Shin Shou  Unknown     NaN
# 11106                             Yami Shibai 4th Season  Unknown     NaN
# 11107                                        Youjo Senki  Unknown     NaN
# 11110  Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou        6     NaN
# 11111       Yuuki Yuuna wa Yuusha de Aru: Yuusha no Shou        6     NaN
#
# [3787 rows x 3 columns]

# %%
anime_df = Report[['name', 'genre', 'rating']]
anime_df
# Out:
#                                                     name  \
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre  rating
# 0                   Drama, Romance, School, Supernatural    9.37
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26
# 2      Action, Comedy, Historical, Parody, Samurai, S...    9.25
# ...

# %%
anime_df.isna().sum()
# Out:
# name        0
# genre      62
# rating    230
# dtype: int64
